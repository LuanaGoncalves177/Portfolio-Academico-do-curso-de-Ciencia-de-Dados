# %% [markdown]
# # Exercício 1

# %% [markdown]
# Responda:
# 1. Qual a diferença entre IA, ML e Deep Learning?
# 2. Dê 3 exemplos de classificação e 3 de regressão do dia a dia.
# 3. Por que dividimos dados em treino e teste?
# 4. O que significa acurácia de 85%?
# 5. Quando usar aprendizado não-supervisionado?

# %% [markdown]
# # Exercício 2

# %%
# Use o dataset Iris (flores) para classificação
from sklearn.datasets import load_iris

iris = load_iris()
X_iris = iris.data
y_iris = iris.target

# Complete:
# 1. Divida em treino/teste
# 2. Treine modelo
# 3. Calcule acurácia
# 4. Quais são as 3 espécies de flores?

# %% [markdown]
# # Exercício 3

# %%
# Preveja preço de casas na Califórnia
california = fetch_california_housing()

# Complete:
# 1. Carregue dados
# 2. Divida treino/teste
# 3. Treine LinearRegression
# 4. Calcule MSE e R²
# 5. O que R² = 0.6 significa?

# %% [markdown]
# # Exercício 4

# %%
# Compare 3 algoritmos no dataset Titanic
# Random Forest, Logistic Regression, Decision Tree
# Qual teve melhor acurácia? Por quê?

# %% [markdown]
# # Exercício 5

# %%
Analise seu modelo e responda:
1. Qual feature foi mais importante?
2. O modelo é melhor em prever sobreviventes ou não-sobreviventes?
3. Em que cenários o modelo erra mais?
4. Como você melhoraria o modelo?
5. Este modelo seria útil na vida real? Por quê?
