# %%
# ============================================================
# CARREGAMENTO DE DADOS
# ============================================================
import pandas as pd

df = pd.read_csv('arquivo.csv')           # Ler CSV
df = pd.read_excel('arquivo.xlsx')        # Ler Excel
df = pd.read_json('arquivo.json')         # Ler JSON
df = pd.read_sql(query, connection)       # Ler SQL
df.to_csv('saida.csv', index=False)       # Salvar CSV
df.to_excel('saida.xlsx')                 # Salvar Excel

# ============================================================
# EXPLORAÇÃO INICIAL
# ============================================================
df.head()              # Primeiras 5 linhas
df.tail()              # Últimas 5 linhas
df.shape               # (linhas, colunas)
df.info()              # Tipos e valores não-nulos
df.describe()          # Estatísticas descritivas
df.columns             # Nomes das colunas
df.dtypes              # Tipos de dados
df.isnull().sum()      # Valores ausentes por coluna
df.nunique()           # Valores únicos por coluna

# ============================================================
# SELEÇÃO DE DADOS
# ============================================================
df['coluna']                    # Uma coluna (Series)
df[['col1', 'col2']]            # Múltiplas colunas
df.loc[0:5, 'coluna']           # Por rótulo
df.iloc[0:5, 0:3]               # Por posição
df[df['coluna'] > 10]           # Filtrar por condição

# ============================================================
# ESTATÍSTICAS
# ============================================================
df['coluna'].mean()             # Média
df['coluna'].median()           # Mediana
df['coluna'].std()              # Desvio padrão
df['coluna'].min()              # Mínimo
df['coluna'].max()              # Máximo
df['coluna'].sum()              # Soma
df['coluna'].count()            # Contagem
df['coluna'].value_counts()     # Frequência de categorias
df['coluna'].unique()           # Valores únicos
df.corr()                       # Matriz de correlação

# ============================================================
# LIMPEZA DE DADOS
# ============================================================
df.dropna()                     # Remover linhas com NaN
df.fillna(valor)                # Preencher NaN
df.drop_duplicates()            # Remover duplicatas
df.rename(columns={'old': 'new'})  # Renomear colunas
df['coluna'].astype(int)        # Converter tipo
df['coluna'].str.lower()        # Minúsculas
df['coluna'].str.strip()        # Remover espaços

# ============================================================
# AGRUPAMENTO E AGREGAÇÃO
# ============================================================
df.groupby('coluna').mean()     # Média por grupo
df.groupby('coluna').sum()      # Soma por grupo
df.groupby('coluna').count()    # Contagem por grupo
df.pivot_table(values='col', index='grp', aggfunc='mean')

# ============================================================
# ORDENAÇÃO
# ============================================================
df.sort_values('coluna')        # Ordenar por coluna
df.sort_values('coluna', ascending=False)  # Decrescente
df.nlargest(10, 'coluna')       # Top 10 maiores
df.nsmallest(10, 'coluna')      # Top 10 menores

# ============================================================
# CRIAR/MODIFICAR COLUNAS
# ============================================================
df['nova_coluna'] = df['col1'] + df['col2']  # Nova coluna
df.drop('coluna', axis=1)       # Remover coluna
df.apply(func)                  # Aplicar função
df['coluna'].map({'A': 1, 'B': 2})  # Mapear valores
